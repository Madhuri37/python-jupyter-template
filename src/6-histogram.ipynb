# %% [markdown]
# ### Exercise 6: Histogram Customization

# %%
import matplotlib.pyplot as plt
data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4, 5]


plt.hist(data, bins=5, color='green')


plt.xlabel('x')
plt.ylabel('y')
plt.title('Histogram visual')

# Show the plot
plt.show()
